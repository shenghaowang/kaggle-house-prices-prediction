# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
# %matplotlib inline
plt.style.use('bmh')
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Data Acquisition

# %%
train_df = pd.read_csv("data/train.csv")
print(train_df.shape)
train_df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
train_info_df = pd.DataFrame(train_df.dtypes)
train_info_df['MissingVal'] = train_df.isnull().sum()
train_info_df['NUnique'] = train_df.nunique()
train_info_df['Count'] = train_df.count()
train_info_df = train_info_df.rename(columns = {0: 'DataType'})
train_info_df
# Out:
#               DataType  MissingVal  NUnique  Count
# Id               int64           0     1460   1460
# MSSubClass       int64           0       15   1460
# MSZoning        object           0        5   1460
# LotFrontage    float64         259      110   1201
# LotArea          int64           0     1073   1460
# Street          object           0        2   1460
# Alley           object        1369        2     91
# LotShape        object           0        4   1460
# LandContour     object           0        4   1460
# Utilities       object           0        2   1460
# LotConfig       object           0        5   1460
# LandSlope       object           0        3   1460
# Neighborhood    object           0       25   1460
# Condition1      object           0        9   1460
# Condition2      object           0        8   1460
# BldgType        object           0        5   1460
# HouseStyle      object           0        8   1460
# OverallQual      int64           0       10   1460
# OverallCond      int64           0        9   1460
# YearBuilt        int64           0      112   1460
# YearRemodAdd     int64           0       61   1460
# RoofStyle       object           0        6   1460
# RoofMatl        object           0        8   1460
# Exterior1st     object           0       15   1460
# Exterior2nd     object           0       16   1460
# MasVnrType      object           8        4   1452
# MasVnrArea     float64           8      327   1452
# ExterQual       object           0        4   1460
# ExterCond       object           0        5   1460
# Foundation      object           0        6   1460
# BsmtQual        object          37        4   1423
# BsmtCond        object          37        4   1423
# BsmtExposure    object          38        4   1422
# BsmtFinType1    object          37        6   1423
# BsmtFinSF1       int64           0      637   1460
# BsmtFinType2    object          38        6   1422
# BsmtFinSF2       int64           0      144   1460
# BsmtUnfSF        int64           0      780   1460
# TotalBsmtSF      int64           0      721   1460
# Heating         object           0        6   1460
# HeatingQC       object           0        5   1460
# CentralAir      object           0        2   1460
# Electrical      object           1        5   1459
# 1stFlrSF         int64           0      753   1460
# 2ndFlrSF         int64           0      417   1460
# LowQualFinSF     int64           0       24   1460
# GrLivArea        int64           0      861   1460
# BsmtFullBath     int64           0        4   1460
# BsmtHalfBath     int64           0        3   1460
# FullBath         int64           0        4   1460
# HalfBath         int64           0        3   1460
# BedroomAbvGr     int64           0        8   1460
# KitchenAbvGr     int64           0        4   1460
# KitchenQual     object           0        4   1460
# TotRmsAbvGrd     int64           0       12   1460
# Functional      object           0        7   1460
# Fireplaces       int64           0        4   1460
# FireplaceQu     object         690        5    770
# GarageType      object          81        6   1379
# GarageYrBlt    float64          81       97   1379
# GarageFinish    object          81        3   1379
# GarageCars       int64           0        5   1460
# GarageArea       int64           0      441   1460
# GarageQual      object          81        5   1379
# GarageCond      object          81        5   1379
# PavedDrive      object           0        3   1460
# WoodDeckSF       int64           0      274   1460
# OpenPorchSF      int64           0      202   1460
# EnclosedPorch    int64           0      120   1460
# 3SsnPorch        int64           0       20   1460
# ScreenPorch      int64           0       76   1460
# PoolArea         int64           0        8   1460
# PoolQC          object        1453        3      7
# Fence           object        1179        4    281
# MiscFeature     object        1406        4     54
# MiscVal          int64           0       21   1460
# MoSold           int64           0       12   1460
# YrSold           int64           0        5   1460
# SaleType        object           0        9   1460
# SaleCondition   object           0        6   1460
# SalePrice        int64           0      663   1460

# %%
quan_train_df = train_df.select_dtypes(include=[np.number])
quan_train_df.drop(['Id'], axis=1, inplace=True)
print(quan_train_df.shape)
print(quan_train_df.columns)
# Out:
# (1460, 37)
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(16, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(quan_train_df.astype(float).corr(), linewidths=0.1, vmax=1.0,
            square=True, cmap=colormap, linecolor='white')

# %% [markdown]
# # II. Feature Missing Values

# %%
train_info_df[train_info_df['MissingVal'] > 0]
# Out:
#              DataType  MissingVal  NUnique  Count
# LotFrontage   float64         259      110   1201
# Alley          object        1369        2     91
# MasVnrType     object           8        4   1452
# MasVnrArea    float64           8      327   1452
# BsmtQual       object          37        4   1423
# BsmtCond       object          37        4   1423
# BsmtExposure   object          38        4   1422
# BsmtFinType1   object          37        6   1423
# BsmtFinType2   object          38        6   1422
# Electrical     object           1        5   1459
# FireplaceQu    object         690        5    770
# GarageType     object          81        6   1379
# GarageYrBlt   float64          81       97   1379
# GarageFinish   object          81        3   1379
# GarageQual     object          81        5   1379
# GarageCond     object          81        5   1379
# PoolQC         object        1453        3      7
# Fence          object        1179        4    281
# MiscFeature    object        1406        4     54

# %%
train_df['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
train_df['PoolQC'].value_counts()
# Out:
# Gd    3
# Fa    2
# Ex    2
# Name: PoolQC, dtype: int64

# %%
train_df['Fence'].value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
